# %% [markdown]
# # 04 - DR Classification & Model Training Experiments
#
# This notebook is used for training and experimenting with PyTorch DR grading models.
# Core pipeline functionality resides in `src/classification/`.
