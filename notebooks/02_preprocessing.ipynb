# %% [markdown]
# # 02 - Preprocessing & Image Quality Experiments
#
# This notebook is used for evaluating fundus image quality metrics, CLAHE parameters, and ROI crop algorithms.
# Core pipeline functionality resides in `src/preprocessing/`.
