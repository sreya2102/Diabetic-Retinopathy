# %% [markdown]
# # 03 - Retinal Structure & Lesion Segmentation Experiments
#
# This notebook is used for prototyping vessel segmentation, optic disc localization, fovea detection, and lesion segmentation.
# Core pipeline functionality resides in `src/segmentation/`.
