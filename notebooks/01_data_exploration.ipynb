# %% [markdown]
# # 01 - Data Exploration & Analysis
#
# This notebook is used for initial exploratory data analysis of fundus image datasets (IDRiD, EyePACS, APTOS).
# Core pipeline functionality resides in `src/`.
