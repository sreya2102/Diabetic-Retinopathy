# %% [markdown]
# # 05 - Evaluation & Benchmarking
#
# This notebook is used for evaluating model performance, computing confusion matrices, sensitivity, specificity, and Quadratic Weighted Kappa.
# Core pipeline functionality resides in `src/evaluation/`.
